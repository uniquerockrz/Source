# %% [markdown]
# # Regression In Neural Networks With Tensor Flow
#
# We will build a regression model with Tensorflow using Neural Networks. We will be predicting a number based on other numbers.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.9.2

# %% [markdown]
# ## Creating Some Data

# %%
# create the features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])


# create the labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# %%
# visualize
plt.scatter(X, y)

# %% [markdown]
# ## Input & Output Shapes

# %%
# Lets look at the shapes of the dataset by default
X.shape, y.shape
# Out:
# ((8,), (8,))

# %%
# Turn numpy arrays into tensors
X = tf.constant(X),
y = tf.constant(y),

X, y
# Out:
# ((<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,),
#  (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>,))

# %% [markdown]
# ## Modelling In Tensorflow

# %% [markdown]
# ### Create The Model

# %%
tf.random.set_seed(42)

# %%
# Create the model using Sequential API

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# %% [markdown]
# ### Compile The Model

# %%
model.compile(loss=tf.keras.losses.mae, optimizer=tf.keras.optimizers.SGD(), metrics=['mae'])

# %% [markdown]
# ### Fit The Model

# %%
model.fit(tf.expand_dims(X, axis=-1), tf.expand_dims(y, axis=-1), epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 12ms/step - loss: 10.8423 - mae: 10.8423
# Epoch 2/5
# 1/1 [==============================] - 0s 12ms/step - loss: 10.7098 - mae: 10.7098
# Epoch 3/5
# 1/1 [==============================] - 0s 10ms/step - loss: 10.5773 - mae: 10.5773
# Epoch 4/5
# 1/1 [==============================] - 0s 9ms/step - loss: 10.4448 - mae: 10.4448
# Epoch 5/5
# 1/1 [==============================] - 0s 8ms/step - loss: 10.3123 - mae: 10.3123

# %%
# another way of creating the model
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.Dense(1))

# %% [markdown]
# ### Make A Prediction

# %%
model.predict([[17.0]])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 8, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 8, 1), dtype=tf.float64, name='dense_1_input'), name='dense_1_input', description="created by layer 'dense_1_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 0s 127ms/step
# array([[[15.741023]]], dtype=float32)
